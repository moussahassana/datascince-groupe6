# %% [markdown]
# # TRAVAUX PRATIQUES GROUPE 6 K-MEANS: Prédiction du cancer de sein

# %% [markdown]
# # 1- Formulation d'une solution
# &emsp;&emsp;Pour aborder ce problème de classification sur le cancer du sein, l'utilisation d'un modèle basé sur l'algorithme K-means pourrait être envisagée pour assigner efficacement les patients aux catégories de témoins sains ou de patientes atteintes de cancer du sein, en se basant sur leurs caractéristiques cliniques.

# %% [markdown]
# # 2- Collecte des données
# &emsp;&emsp;Nous avons recueilli le dataset sur kaggle: https://www.kaggle.com/datasets/tanshihjen/coimbra-breastcancer/data
#
# &emsp;&emsp;Cet ensemble de données présente une exploration complète des caractéristiques cliniques observées ou mesurées chez 64 patientes atteintes d'un cancer du sein et 52 témoins sains. L'ensemble de données comprend à la fois des attributs quantitatifs et des étiquettes correspondantes pour une analyse et une modélisation efficaces.
#
# **Attributs quantitatifs :**
#
# - **Âge (années):** Âge des individus.
# - **IMC (kg/m²):** Indice de masse corporelle, une mesure de la graisse corporelle basée sur le poids et la taille.
# - **Glucose (mg/dL):** Glycémie, un indicateur métabolique important.
# - **Insuline (µU/mL):** Taux d'insuline, une hormone liée à la régulation du glucose.
# - **HOMA:** Homeostatic Model Assessment, une méthode d’évaluation de la résistance à l’insuline et de la fonction des cellules bêta.
# - **Leptine (ng/mL):** Taux de leptine, une hormone impliquée dans la régulation de l'appétit et de l'équilibre énergétique.
# - **Adiponectine (µg/mL):** Taux d'adiponectine, une protéine associée à la régulation métabolique.
# - **Résistine (ng/mL):** Niveaux de résistine, une protéine impliquée dans la résistance à l'insuline.
# - **MCP-1 (pg/dL):** Monocyte Chemoattractant Protein-1, une cytokine impliquée dans l'inflammation.
#
# **Étiquettes:**
#
# - **1 :** Témoins sains
# - **2 :** Patientes atteintes d’un cancer du sein

# %% [markdown]
# # 3-Prétraitement des données
# ## Importation des bibliothèques

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from kneed import KneeLocator 
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
#Chargement du dataset
data=pd.read_csv('Coimbra_breast_cancer_dataset.csv')

# %%
# Ouverture du dataset
data.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
##Exploration des données

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             116 non-null    int64
#  1   BMI             116 non-null    float64
#  2   Glucose         116 non-null    int64
#  3   Insulin         116 non-null    float64
#  4   HOMA            116 non-null    float64
#  5   Leptin          116 non-null    float64
#  6   Adiponectin     116 non-null    float64
#  7   Resistin        116 non-null    float64
#  8   MCP.1           116 non-null    float64
#  9   Classification  116 non-null    int64
# dtypes: float64(7), int64(3)
# memory usage: 9.2 KB

# %%
# Répartition des classes
data['Classification'].value_counts().plot.pie(autopct='%1.1f%%', labels=['Témoins sains', 'Patientes cancer du sein'])
plt.title('Répartition des classes')
plt.show()

# %%
# Visualisation des valeurs manquantes
msno.matrix(data)
# Out:
# <Axes: >

# %%
# Supprimer les duplications
data = data.drop_duplicates()

# Supprimer les colonnes avec des valeurs manquantes
data = data.dropna(axis=1)

# Normalisation des variables numériques
scaler = StandardScaler()
data_scaled = pd.DataFrame(scaler.fit_transform(data.drop('Classification', axis=1)), columns=data.columns[:-1])

# Affichage des données prétraitées
print(data_scaled)
# Out:
#           Age       BMI   Glucose   Insulin      HOMA    Leptin  Adiponectin  \
# 0   -0.579794 -0.816675 -1.239222 -0.728739 -0.614282 -0.932334    -0.070222
# 1    1.601821 -1.378751 -0.258299 -0.688038 -0.548240 -0.930413    -0.697350
# 2    1.539489 -0.891764 -0.302887 -0.550073 -0.464752 -0.454219     1.797998
# 3    0.666843 -1.243303 -0.927110 -0.676965 -0.574210 -0.876021    -0.441945
# 4    1.788816 -1.294601 -0.258299 -0.644743 -0.521081 -1.042682    -0.786881
# ..        ...       ...       ...       ...       ...       ...          ...
# 111 -0.766789 -0.146468 -0.258299 -0.666590 -0.534786  1.469335     0.281654
# 112  0.292852 -0.148468  0.098400 -0.546881 -0.435039 -0.741611     1.649470
# 113  0.479848  0.893855 -0.035362 -0.427172 -0.365106  1.825348     1.813843
# 114  0.916171 -0.398546 -0.704173 -0.717467 -0.585883 -0.086651     3.459038
# 115  1.788816 -0.080447  1.792721  0.987394  1.125766  3.333167     0.576644
#
#      Resistin     MCP.1
# 0   -0.545517 -0.341251
# 1   -0.864214 -0.191224
# 2   -0.441660  0.058214
# 3   -0.158867  1.142718
# 4   -0.336352  0.694716
# ..        ...       ...
# 111 -0.305255 -0.773527
# 112 -0.600299 -0.593717
# 113 -0.356320 -0.640491
# 114 -0.928577 -0.412832
# 115 -0.841036 -1.290747
#
# [116 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# Supposons que df_scaled contient vos données prétraitées

# Séparer les données en ensembles d'entraînement 20 instances et 20 instances de test 
train_data, test_data = train_test_split(data_scaled, test_size=20, train_size=20, random_state=42)

# Afficher les tailles des ensembles d'entraînement et de test
print("Taille de l'ensemble d'entraînement :", len(train_data))
print("Taille de l'ensemble de test :", len(test_data))
print("test data",test_data)
print("train data",train_data)
# Out:
# Taille de l'ensemble d'entraînement : 20
# Taille de l'ensemble de test : 20
# test data           Age       BMI   Glucose   Insulin      HOMA    Leptin  Adiponectin  \
# 83   0.853839 -0.414510  0.633449  0.038199  0.048756 -0.395268    -0.689012
# 4    1.788816 -1.294601 -0.258299 -0.644743 -0.521081 -1.042682    -0.786881
# 42   1.103166 -0.056440 -0.570411 -0.480342 -0.442695 -0.849462    -0.173189
# 40   1.165498  0.327361 -0.659586 -0.462486 -0.439659  0.101931    -0.412534
# 10  -1.452439 -1.222801 -0.882523 -0.652724 -0.559123 -0.630618     0.429883
# 47   1.290162 -0.456564 -1.685096 -0.648833 -0.600005 -1.046159     0.056712
# 110 -0.205803  1.694103  0.945560  0.189332  0.220884  3.280289    -0.318601
# 36   0.542180  0.731523 -0.704173 -0.581696 -0.509970 -0.543987    -0.867913
# 70  -0.766789 -1.464876 -0.258299 -0.655617 -0.527902 -0.992914     0.952353
# 11  -1.764099 -0.914706 -0.704173 -0.433855 -0.427308  0.469881     2.427305
# 45   0.542180  0.023585 -0.347474 -0.396047 -0.373289 -0.092620    -0.371133
# 26  -0.455130  2.200011  0.365924 -0.330107 -0.259872  1.048407    -0.809129
# 94   0.168189  0.730086  1.480609  2.006919  1.941648  0.587836    -0.260713
# 53  -0.766789 -1.350842 -1.060873 -0.543888 -0.513645 -0.987527    -0.285226
# 18   0.417516  1.389953 -0.124537 -0.557156 -0.457102 -0.282893    -0.692458
# 0   -0.579794 -0.816675 -1.239222 -0.728739 -0.614282 -0.932334    -0.070222
# 56  -0.953785 -1.244825 -0.213712 -0.699610 -0.553460 -0.394362    -0.252130

    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(train_data)
    distortions.append(kmeans.inertia_)

# Afficher la courbe elbow
plt.figure(figsize=(8, 6))
plt.plot(range(1, 14), distortions, marker='o')
plt.title('Méthode du coude pour trouver le nombre optimal de clusters (k)')
plt.xlabel('Nombre de clusters (k)')
plt.ylabel('Distorsion')
plt.show()

# Utiliser le KneeLocator pour trouver le nombre optimal de clusters (k)
# Out:
# Nombre optimal de clusters (k): 5

# %%
# Utiliser le nombre optimal de clusters pour entraîner le modèle K-Means
k_optimal = optimal_k
kmeans = KMeans(n_clusters=k_optimal, random_state=42)
kmeans.fit(train_data)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Ajouter les étiquettes de cluster à l'ensemble d'entraînement
train_data['Cluster'] = kmeans.labels_

# Prédire les clusters sur l'ensemble de test
test_data['Cluster'] = kmeans.predict(test_data.drop('Cluster', axis=1, errors='ignore'))

# %%
# Calculer les corrdonnees courbe ROC
fpr, tpr, thresholds = roc_curve(test_data['Classification'], test_data['Cluster'])
roc_auc = auc(fpr, tpr)

# Tracer la courbe ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Taux de faux positifs (FPR)')
plt.ylabel('Taux de vrais positifs (TPR)')
plt.title('Courbe ROC')
plt.legend(loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Classification'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Calculer les corrdonnees courbe ROC
# ----> 2 fpr, tpr, thresholds = roc_curve(test_data['Classification'], test_data['Cluster'])
#       3 roc_auc = auc(fpr, tpr)
#       5 # Tracer la courbe ROC
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Classification'

# %%
# Out:
#   Cell In[25], line 38
#     print("Coefficient de silhouette :", silhouette_coefficient)`
#                                                                 ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd

def euclidean_distance(a, b):
    return np.linalg.norm(a - b)


def calculate_silhouette_coefficient(data, clusters):
    n = len(data)
    silhouette_values = np.zeros(n)
    
    for i in range(n):
        cluster_index = clusters[i]
        cluster_points = data[clusters == cluster_index]
        a_i = np.mean([euclidean_distance(data[i], point) for point in cluster_points])
        
        b_i = float('inf')
        for j in range(len(clusters)):
            if clusters[j] != cluster_index:
                other_cluster_points = data[clusters == clusters[j]]
                b_ij = np.mean([euclidean_distance(data[i], point) for point in other_cluster_points])
                b_i = min(b_i, b_ij)
        
        silhouette_values[i] = (b_i - a_i) / max(a_i, b_i)
    
    return np.mean(silhouette_values)

# Exemple d'utilisation :
# Remplacez data par votre DataFrame pandas et clusters par les étiquettes de cluster obtenues à partir de votre algorithme de clustering

data = pd.DataFrame({
    'Age': [-0.579794, 1.601821, 1.539489, 0.666843],
    'BMI': [-0.816675, -1.378751, -0.891764, -1.243303],
    'Glucose': [-1.239222, -0.258299, -0.302887, -0.927110],
    'Insulin': [-0.728739, -0.688038, -0.550073, -0.676965],
    'HOMA': [-0.614282, -0.548240, -0.464752, -0.574210],
    'Leptin': [-0.932334, -0.930413, -0.454219, -0.876021],
    'Adiponectin': [-0.070222, -0.697350, 1.797998, -0.441945],
    'Resistin': [-0.545517, -0.864214, -0.441660, -0.158867],
    'MCP.1': [-0.341251, -0.191224, 0.058214, 1.142718],
    'cluster': [0, 1, 0, 1]
})

clusters = data['cluster'].values
data = data.drop(columns=['cluster']).values

silhouette_coefficient = calculate_silhouette_coefficient(data, clusters)
print("Coefficient de silhouette :", silhouette_coefficient)
# Out:
# Coefficient de silhouette : 0.5039869007379285

# %%
# Out:
# Coefficient de silhouette : 0.5039869007379285
